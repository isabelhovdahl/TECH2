# %% [markdown]
# # 04 - Functions
#
# Up until now, we have executed our programs as a series of instructions. However, most programs consist of distinct groups of instructions designed to perform a specific task, i.e., routines. In Python, routines are known as *functions*.
#
# A function is a block of code that only runs when it is called. Creating functions offers several advantages:
# - **Code reusability:** define the function once and use it whenever needed — don't repeat yourself (DRY)!
# - **Organization:** break the program down into smaller, manageable units, which improves code organization.
# - **Readability:** giving descriptive names to functions can make the code easier to navigate (for you and others!).
# - **Abstraction:** you don't need to know how the sausage is made (i.e., the code) to use a function — only how to call it.
#
# This notebook shows how we can create our own **self-defined functions** in Python.

# %% [markdown]
# ## Defining a function
#
# A function is a **named** group of instructions that accomplishes a **specific task**.
#
# We have already used several of Python's built-in functions, e.g. `print`, `len`, and `type`.

# %% [markdown]
# A function typically has four characteristics:
# 1. Name
# 2. Task
# 3. Input (also known as parameters)
# 4. Output

# %% [markdown]
# For example, we have used `len` to calculate the length of sequences, e.g. strings and lists:
#
# 1. Name: `len`
# 2. Task: calculate the length of a sequence
# 3. Input: a sequence
# 4. Output: an integer

# %%
len([1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# A function definition has a **header** and a **body**.
#
# ```
# def <name>(<parameters>):
#     <statements>
#     return <value>
# ```
#
# The header starts with `def`, gives the function a name, lists its **parameters** in brackets, and ends with a **colon**. The body is **indented** underneath, exactly as it was for `if` and for `for`. The `return` statement says what the function hands back.

# %% [markdown]
# Let's write a program that calculates the average of three numbers.

# %%
num1 = 10
num2 = 9
num3 = 4

avg = (num1 + num2 + num3) / 3

print(avg)

# %% [markdown]
# To increase the reusability of our program, we can place this code inside a function called `avg3`.

# %%
def avg3(num1, num2, num3):
    avg = (num1 + num2 + num3) / 3
    return avg

# %% [markdown]
# > 📝 **Note:** A function must be *defined* (i.e., its code cell must have been run) before it can be used elsewhere in the program — the order cells are *run* in matters, not just the order they appear in the notebook.

# %% [markdown]
# Once a function is defined, we can use it as many times as we want, each time supplying the *function call* with new inputs.

# %%
mean = avg3(num1=10, num2=9, num3=4)

print(mean)

# %%
mean = avg3(num1=1.7, num2=9, num3=7)

print(mean)

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Create a function called <TT>avg4</TT> that calculates and returns the average of four numbers.
# </p>
# </div>

# %% [markdown]
# To further increase the reusability of our program, we can instead create a function called `avg_lst` that calculates the average of a *list* of numbers. The function takes only one input (the list of numbers) and returns the average of that list.

# %%
def avg_lst(number_lst):

    lst_sum = sum(number_lst)     # sum of the numbers
    lst_length = len(number_lst)  # length of the list
    avg = lst_sum / lst_length    # calculate the mean

    return avg

# %% [markdown]
# We can now use the function to calculate the average of a list of numbers, independent of the length of the list.

# %%
mean = avg_lst(number_lst=[10, 9, 4, 5, 9, 10, 0])

print(mean)

# %%
mean = avg_lst(number_lst=[1, 2, 3])

print(mean)

# %% [markdown]
# ### Non-value-returning functions
#
# We have so far looked at **value-returning** functions:
# - They use the `return` statement to produce an output
# - The output can be stored by assigning it to a variable
#
# There are also **non-value-returning** functions:
# - They have no `return` statement
# - But they have other desirable side effects (e.g., printing something)
# - Their output is not stored in a variable name

# %% [markdown]
# For example, let's modify `avg_lst` so that it *displays* the average instead of returning it, by substituting the `return` statement with a `print` statement.

# %%
def avg_lst(number_lst):

    lst_sum = sum(number_lst)
    lst_length = len(number_lst)
    avg = lst_sum / lst_length

    print(f"The mean is {avg:.2f}")  # no return statement

# %% [markdown]
# With non-value-returning functions, we call the function without assigning it to a variable.

# %%
avg_lst(number_lst=[10, 9, 4, 5, 9, 10, 0])

# %% [markdown]
# > 📝 **Note:** If you assign the result of a non-value-returning function call to a variable, that variable will simply store `None` — Python's default return value when a function has no `return` statement.

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Write a function called <TT>to_fahrenheit</TT> that takes a temperature in Celsius and <b>returns</b> the temperature in Fahrenheit, using the formula:</p>
# <pre><code>F = (9 / 5) * C + 32</code></pre>
# <ul>
# <li>Call the function for 20 degrees Celsius and display the result.</li>
# <li>Now replace the <TT>return</TT> statement with a <TT>print</TT> statement, and try to use the result in a calculation: <TT>to_fahrenheit(20) + 10</TT>. What happens, and why?</li>
# </ul>
# </div>

# %% [markdown]
# ## Function input
#
# The names in the function header are its **parameters**. The values we hand over in the call are its **arguments**. There is more than one way to hand them over.

# %%
def division(num1, num2):
    result = num1 / num2
    return result

# %% [markdown]
# **By name**: write `parameter=value` in the function call to pass an argument to a specific parameter. The order of the arguments then does not matter.

# %%
print(division(num1=2, num2=-5))
print(division(num2=-5, num1=2))

# %% [markdown]
# **By position**: the first argument goes to the first parameter, the second to the second. The order is then the whole story — swapping it changes which parameter receives which value, and therefore the result.

# %%
print(division(2, -5))
print(division(-5, 2))

# %% [markdown]
# The two styles can be mixed, but positional arguments must come first - Python cannot work out what an unnamed value refers to once the order has been abandoned.

# %%
# SyntaxError
division(num2 = 1, 10)

# %% [markdown]
# By default, a function must be called with all of its parameters filled in.

# %%
# TypeError
division(5)

# %% [markdown]
# But a parameter can be given a **default** value in the header, which makes it optional: supply it and yours is used, leave it out and the default is used.

# %%
def division(num1, num2=10):
    result = num1 / num2
    return result

# %%
division(10)

# %%
division(10, 5)

# %% [markdown]
# Defaults are how a function can be simple in the common case and still flexible in the rare one. `print` works this way: `print(x)` ends the line, and `print(x, end=" ")` does not, because `end` has a default of `"\n"`.

# %% [markdown]
# Parameters **with** defaults must come after parameters **without** them.

# %%
# SyntaxError
def division(num1=10, num2):
    result = num1 / num2
    return result

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Create a function called <TT>power</TT> that raises a number to the <i>n</i>th power. The function should have two parameters: the number and the exponent. As a default, the function should raise the number to the power of two. The function should return the result.</p>
# </div>

# %% [markdown]
# ## Function output
#
# The return value of a function can be stored in a variable, or used directly as part of a larger expression.

# %%
def division(num1, num2=10):
    result = num1 / num2
    return result

# %% [markdown]
# We can store the result of a function call in a variable, and use that variable in another function call.

# %%
res1 = division(6, 2)
res2 = division(12, res1)

print(res2)

# %% [markdown]
# Alternatively, we can pass a function call directly as an argument to another function call.

# %%
res3 = division(12, division(6, 2))

print(res3)

# %% [markdown]
# We can also use multiple function calls within a single expression, or directly inside a conditional.

# %%
division(2, 4) * division(8, 3)

# %%
a = 5
b = 3

if division(a, b) >= 1:
    print("Equal or larger than 1")
else:
    print("Smaller than 1")

# %% [markdown]
# A function can also return *multiple* values at once.

# %%
def calculations(num1, num2):

    res1 = num1 * num2
    res2 = num1 / num2

    return res1, res2  # return two values

results = calculations(10, 5)

results

# %% [markdown]
# > 📝 **Note:** Multiple return values are actually packed into a single *tuple* — recall from the first notebook that tuples are created with parentheses `()` and can hold multiple values.

# %% [markdown]
# We can *unpack* a tuple directly into separate variables.

# %%
res1, res2 = calculations(10, 5)

print(res1)
print(res2)

# %% [markdown]
# ### `return` exits the function
#
# `return` does two things: it hands a value back to the caller, and it **ends the function immediately**. Nothing after a `return` in the same block is ever run.

# %%
def double(number):
    return number * 2
    print("This line never runs.")

double(21)

# %% [markdown]
# That is not a limitation — it is how a function with several possible answers is written. Each branch returns as soon as it knows the answer, so there is no need for an `else`.

# %%
def describe(number):
    if number > 0:
        return "positive"
    if number < 0:
        return "negative"
    return "zero"

print(describe(4.2))
print(describe(-1))
print(describe(0))

# %% [markdown]
# ### `return` inside a loop
#
# Recall that `break` leaves the innermost loop and nothing more. `return` is stronger: it leaves the loop **and** the function in one go. When we are searching for something, that is usually exactly what we want.

# %%
def first_negative(number_lst):
    for num in number_lst:
        if num < 0:
            return num  # leaves both the loop and the function

    return None  # only reached if no negative number was found

print(first_negative([3, 7, -8, -10]))
print(first_negative([3, 7, 8, 10]))

# %% [markdown]
# Note the last line of that function. Without it, a list containing no negative number would simply reach the end of the function body — and, as we will see next, hand back `None` by accident rather than on purpose.

# %% [markdown]
# ### A function with no `return` returns `None`
#
# Since `return` is the only way a value comes out of a function, a function that reaches the end of its body without meeting one hands back `None`. This is easy to do by accident when only some of the branches return.

# %%
def check_number(num1, num2):
    if num1 > num2:
        return 0

# %%
res = check_number(20, 10)

print(res)

# %%
res = check_number(10, 20)

print(res)

# %% [markdown]
# `None` is a perfectly good value, so it travels quietly through the program until it meets something that cannot cope with it — often far away from the function that produced it.

# %%
# TypeError (because "res" is None)
res * 100

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Predict what each of the three functions below displays, <b>before</b> you run anything:</p>
# <pre><code>def square(number):
#     result = number ** 2
#
# print(square(5))</code></pre>
#
# <pre><code>def first_long_name(name_lst):
#     for name in name_lst:
#         if len(name) > 5:
#             return name
#
# print(first_long_name(["Ole", "Jenny", "Kristian", "Jonas"]))</code></pre>
#
#
# <pre><code>def grade(score):
#     if score >= 60:
#         return "pass"
#
# print(grade(45))</code></pre>
# <p> Then run them and check. For the two that displayed <TT>None</TT>, work out which rule from this section explains why. Finally, rewrite <TT>grade</TT> so that it returns <TT>"fail"</TT> instead of <TT>None</TT> when the score is below 60 — then work out what <TT>first_long_name</TT> returns when no name in the list is longer than five characters, and give it the same treatment.</p>
# </div>

# %% [markdown]
# ## Scope and side effects
#
# A function is easiest to reuse when it is a self-contained "black box": everything it needs comes in through the brackets, and everything it produces comes out through `return`. There are two common ways that breaks down.

# %% [markdown]
# ### Local versus global variables
#
# Variables created *inside* a function are *local* variables. They are not available outside the function, unless explicitly returned.

# %%
def exp2(num):
    exponent = 2  # local variable
    return num**exponent

# %% [markdown]
# We cannot access a local variable outside of the function where it was created.

# %%
# NameError
exponent

# %% [markdown]
# Local variables are actually great! They let us reuse variable names in different functions without any name conflicts. For example, `exponent` is local to both `exp2` and `exp3` below, and can have a different value in each, even though they share the same name.

# %%
def exp3(num):
    exponent = 3  # local variable
    return num**exponent

exp3(4)

# %% [markdown]
# The *scope* of a variable is the part of the program where the variable is "visible," i.e., where we can access its value. Variables defined outside of any function have **global** scope, and are called *global* variables.

# %%
num = 10  # global variable

# %% [markdown]
# Functions can read global variables even if they are not passed in explicitly as an argument.

# %%
n = 2  # global variable

def exp2(num):
    return num**n  # uses the global variable "n"

exp2(num=4)

# %% [markdown]
# > ⚠️ **Warning:** Relying on global variables inside a function is generally considered bad practice. It breaks the idea of a function as a self-contained "black box" that only depends on its inputs, which makes code harder to reuse and reason about — and easier to break by accident.
# >
# > Reading a global *constant* that never changes (e.g. a fixed conversion rate) is common and reasonably safe. The real risk is a function silently depending on a variable that could change elsewhere in the program, without that dependency being visible in the function's parameters.

# %% [markdown]
# Instead, every variable a function needs should either be defined *inside* the function (as `exponent` was in `exp2` above), or passed in explicitly as a parameter.

# %%
n = 2  # global variable

def exp2(num, exponent):
    return num**exponent

exp2(4, n)  # global variable passed as an explicit argument

# %% [markdown]
# ### Mutable arguments
#
# Unlike numbers and strings, lists and dictionaries are *mutable*. If a function modifies a list or dictionary that was passed in as an argument, the change is visible outside the function too — even without a `return` statement.

# %%
def add_item(lst):
    lst.append("new item")

fruits = ["apple", "banana"]
add_item(fruits)

print(fruits)

# %% [markdown]
# Compare this to passing a number, which is immutable — reassigning the parameter inside the function has no effect on the original variable.

# %%
def add_one(num):
    num = num + 1

x = 5
add_one(x)

print(x)

# %% [markdown]
# > ⚠️ **Warning:** This is another way a function's behavior can have hidden side effects beyond its `return` value — similar to the problem with global variables above. If a function is supposed to modify a list or dictionary, make that intention clear (e.g. in the function's name, or by also returning the modified object).

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Consider the program below:</p>
# <pre><code>tax_rate = 0.25</code></pre>
#
# <pre><code>def add_total(price_lst):
#     total = sum(price_lst) * (1 + tax_rate)
#     price_lst.append(total)
#     return price_lst</code></pre>
#
# <pre><code>prices = [100, 250, 80]
# receipt = add_total(prices)</code></pre>
#
# <pre><code>print(receipt)
# print(prices)</code></pre>
# <ul>
# <li>What do the two <TT>print</TT> statements display? Predict the output <b>before</b> you run the code.</li>
# <li>Why does <TT>prices</TT> change, even though we assigned the result of the function call to a new variable called <TT>receipt</TT>?</li>
# <li>Rewrite <TT>add_total</TT> so that <TT>tax_rate</TT> is passed in as an explicit parameter, and so that the original list is left unchanged.</li>
# </ul>
# </div>

# %% [markdown]
# ## Building a program out of functions
#
# Due to the complexity of many programs, we often prefer to place our code inside one or several functions, to increase readability and reusability. This also keeps the namespace of our program smaller, i.e., fewer global variables to keep track of.

# %% [markdown]
# We can make function calls inside another function.

# %%
def power(num, exponent):
    res = num**exponent
    return res

def print_result(a, b):
    res = power(a, b)  # function call to "power"
    print(res)

print_result(3, 2)

# %% [markdown]
# To organize our code, it is common to use a single function to run the entire program.

# %% [markdown]
# > 📝 **Note:** It is conventional to name this "mother" function `main` — the function that runs the whole program.

# %% [markdown]
# The `main` function should make all of the necessary function calls to run the program, and it should return and/or display the outcome.

# %%
def power(num, exponent=2):
    res = num**exponent
    return res

def main():  # "main" takes no input

    # Define local variables
    number = 3
    exponent = 2

    # Function call to "power"
    res = power(number, exponent)

    # Print result
    print(f"{number}^{exponent} = {res:.2f}")

# %% [markdown]
# We can now run the entire program by simply calling `main`.

# %%
main()
